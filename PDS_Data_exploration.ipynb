# %%
import pandas as pd
import numpy as np

# %%
racine = "C:/Users/sebastien.liandrat/Box/Dossier Personnel de Sébastien LIANDRAT/Codes/Projet DataScientest/Dataset2/"
fichier = "data2021.csv"

# %%
df = pd.read_csv(racine + fichier)
# Out:
# C:\Users\sebastien.liandrat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3331: DtypeWarning: Columns (2,3,8,12,28,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_reduit = df.iloc[0:20]
df_reduit.to_csv(racine + fichier + "_reduit.csv")

# %%
df.columns[1:20]
# Out:
# Index(['Country', 'VFN', 'Mp', 'Mh', 'Man', 'MMS', 'Tan', 'T', 'Va', 'Ve',
#        'Mk', 'Cn', 'Ct', 'Cr', 'r', 'm (kg)', 'Mt', 'Enedc (g/km)',
#        'Ewltp (g/km)'],
#       dtype='object')

# %%
df.columns[20:]
# Out:
# Index(['W (mm)', 'At1 (mm)', 'At2 (mm)', 'Ft', 'Fm', 'ec (cm3)', 'ep (KW)',
#        'z (Wh/km)', 'IT', 'Ernedc (g/km)', 'Erwltp (g/km)', 'De', 'Vf',
#        'Status', 'year', 'Date of registration', 'Fuel consumption ',
#        'Electric range (km)'],
#       dtype='object')

# %%
df.head()
# Out:
#          ID Country                  VFN                         Mp  \
# 0  57566673      IS  IP-01-JMB-2018-0001  RENAULT-NISSAN-MITSUBISHI
# 1  57566674      IS  IP-01-JMB-2018-0001  RENAULT-NISSAN-MITSUBISHI
# 2  57566675      IS  IP-01-JMB-2018-0001  RENAULT-NISSAN-MITSUBISHI
# 3  57566676      IS  IP-01-JMB-2018-0001  RENAULT-NISSAN-MITSUBISHI
# 4  57566677      IS  IP-01-JMB-2018-0001  RENAULT-NISSAN-MITSUBISHI
#
#                               Mh                            Man  MMS  \
# 0  MITSUBISHI MOTORS CORPORATION  MITSUBISHI MOTORS CORPORATION  NaN
# 1  MITSUBISHI MOTORS CORPORATION  MITSUBISHI MOTORS CORPORATION  NaN
# 2  MITSUBISHI MOTORS CORPORATION  MITSUBISHI MOTORS CORPORATION  NaN
# 3  MITSUBISHI MOTORS CORPORATION  MITSUBISHI MOTORS CORPORATION  NaN
# 4  MITSUBISHI MOTORS CORPORATION  MITSUBISHI MOTORS CORPORATION  NaN
#
#                    Tan    T     Va  ...   IT Ernedc (g/km) Erwltp (g/km)  De  \
# ...

# %%
df.describe()
# Out:
#                  ID  MMS          r        m (kg)            Mt  Enedc (g/km)  \
# count  9.920108e+06  0.0  9920108.0  9.920076e+06  7.983251e+06  2.417634e+06
# mean   4.709523e+07  NaN        1.0  1.489677e+03  1.616466e+03  4.914571e+01
# std    1.538232e+07  NaN        0.0  3.367757e+02  3.540105e+02  5.335402e+01
# min    1.000000e+00  NaN        1.0  5.900000e+02  5.060000e+02  0.000000e+00
# 25%    4.665304e+07  NaN        1.0  1.250000e+03  1.365000e+03  0.000000e+00
# 50%    5.166623e+07  NaN        1.0  1.433000e+03  1.556000e+03  3.400000e+01
# 75%    5.487999e+07  NaN        1.0  1.674000e+03  1.805000e+03  1.040000e+02
# max    1.496950e+08  NaN        1.0  4.610000e+03  4.272000e+03  4.520000e+02
#
#        Ewltp (g/km)        W (mm)      At1 (mm)      At2 (mm)      ec (cm3)  \
# count  9.836149e+06  9.902924e+06  8.359068e+06  8.354696e+06  8.919498e+06
# mean   1.147725e+02  2.656181e+03  1.551759e+03  1.554185e+03  1.526805e+03
# ...

# %%
df.info(null_counts = True)
# Out:
# C:\Users\sebastien.liandrat\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   """Entry point for launching an IPython kernel.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9920108 entries, 0 to 9920107
# Data columns (total 38 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   ID                    9920108 non-null  int64
#  1   Country               9920108 non-null  object
#  2   VFN                   8915632 non-null  object
#  3   Mp                    9602760 non-null  object
#  4   Mh                    9920108 non-null  object
#  5   Man                   9920108 non-null  object
#  6   MMS                   0 non-null        float64
#  7   Tan                   9896073 non-null  object
#  8   T                     9916530 non-null  object
#  9   Va                    9901897 non-null  object
# ...

# %%
# (2,3,8,12,28,35) have mixed types

# %%
df["Country"].value_counts(normalize = True).plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
for col in df.columns[0:5]:
    print(df[col].value_counts(normalize = True))
# Out:
# 57566673    1.008054e-07
# 51327866    1.008054e-07
# 51327868    1.008054e-07
# 51327869    1.008054e-07
# 51327870    1.008054e-07
#                 ...
# 45559975    1.008054e-07
# 45559976    1.008054e-07
# 45559977    1.008054e-07
# 45559978    1.008054e-07
# 53332078    1.008054e-07
# Name: ID, Length: 9920108, dtype: float64
# DE    0.255051
# FR    0.179220
# IT    0.146820
# ES    0.091576
# PL    0.044376
# BE    0.038688
# NL    0.031801
# SE    0.029779
# AT    0.024097
# CZ    0.020265
# DK    0.018217
# NO    0.017727
# PT    0.014731
# RO    0.012206
# HU    0.011617
# IE    0.010518
# GR    0.010107
# FI    0.009590
# SK    0.007625
# SI    0.005230
# HR    0.004589
# LU    0.004128
# LT    0.003119
# BG    0.002446
# EE    0.002250
# LV    0.001428
# IS    0.001246
# CY    0.001056
# MT    0.000499
# Name: Country, dtype: float64
# IP-0110-JT1-1               1.212354e-02
# IP-JAA1MTPJT4A_000-VF1-1    9.673683e-03
# IP-HMR____MA5_1315-VF7-0    9.097616e-03
# ...

# %%
for col in df.columns[5:10]:
    print(df[col].value_counts(normalize = True))
# Out:
# VOLKSWAGEN AG                                   1.100010e-01
# PSA AUTOMOBILES SA                              8.165677e-02
# RENAULT SAS                                     8.096222e-02
# BAYERISCHE MOTOREN WERKE AG                     6.617609e-02
# TOYOTA MOTOR EUROPE NV SA                       6.427339e-02
#                                                     ...
# KUNDENBETREUUNG                                 1.008054e-07
# GM KOREA COMPANY                                1.008054e-07
# KARMA AUTOMOTIVE LLC                            1.008054e-07
# HUNAN JIANGNAN AUTOMOBILE MANUFACTURE CO LTD    1.008054e-07
# FORD MOTOR COMPANY OF AUSTRALIA LIMITED         1.008054e-07
# Name: Man, Length: 100, dtype: float64
# Series([], Name: MMS, dtype: float64)
# E2*2007/46*0639*15       1.525635e-02
# E2*2007/46*0639*12       1.497968e-02
# E2*2007/46*0639*13       1.308782e-02
# E2*2007/46*0639*14       9.757911e-03
# E6*2007/46*0437*01       9.039343e-03
# ...

# %%
for col in df.columns[15:20]:
    print(df[col].value_counts(normalize = True))
# Out:
# 1    1.0
# Name: r, dtype: float64
# 1165.0    3.201840e-02
# 1055.0    3.030078e-02
# 1395.0    2.497884e-02
# 1280.0    2.008694e-02
# 1505.0    1.639504e-02
#               ...
# 2930.0    1.008057e-07
# 2914.0    1.008057e-07
# 2933.0    1.008057e-07
# 3189.0    1.008057e-07
# 2891.0    1.008057e-07
# Name: m (kg), Length: 2120, dtype: float64
# 1999.0    5.869413e-03
# 1942.0    4.095449e-03
# 1997.0    3.921084e-03
# 1525.0    3.750227e-03
# 1905.0    3.257445e-03
#               ...
# 3274.0    1.252623e-07
# 3599.0    1.252623e-07
# 3623.0    1.252623e-07
# 3478.0    1.252623e-07
# 3275.0    1.252623e-07
# Name: Mt, Length: 2204, dtype: float64
# 0.0      4.130555e-01
# 34.0     2.120255e-02
# 35.0     1.894042e-02
# 26.0     1.786788e-02
# 43.0     1.722180e-02
#              ...
# 1.0      4.136275e-07
# 343.0    4.136275e-07
# 323.0    4.136275e-07
# 333.0    4.136275e-07
# 315.0    4.136275e-07
# Name: Enedc (g/km), Length: 325, dtype: float64
# 0.0      1.015252e-01
# ...

# %%
for col in df.columns[20:25]:
    print(df[col].unique())
    print(df[col].value_counts(normalize = True))
# Out:
# [2670. 2673. 3006. 3400. 3000. 2873. 2999. 2788. 2786. 2996. 2675. 2450.
#  2928. 2710. 2729. 2769. 2771. 2655. 2995. 3135. 2495. 2618. 2700. 2500.
#  2815. 2600. 2581. 2770. 2827. 2629. 2570. 2745. 3128. 2835. 2839. 2975.
#  2984. 2579. 2755. 2604. 2551. 2590. 2593. 2619. 2712. 3275. 2435. 2840.
#  2549. 3498. 2857. 3216. 2665. 2725. 3025. 2935. 2785. 2875. 2705. 2639.
#  2417. 2780. 2865. 2605. 2540. 3008. 2765. 2707. 2636. 2829. 2550. 2650.
#  2561. 2730. 2915. 2322. 2960. 2965. 2680. 2690. 2790. 2640. 2560. 2610.
#  2667. 2588. 2702. 2669. 2583. 2941. 2672. 2722. 2530. 2250. 2671. 2870.
#  2517. 2520. 2340. 2836. 2400. 2538. 2850. 2787. 2825. 2864. 2660. 2895.
#  2630. 2624. 3200. 3430. 2900. 2904. 2510. 2923. 2899. 3105. 2720. 3210.
#  2493. 2890. 2807. 2662. 2580. 2663. 2525. 2735. 2697. 2539. 2621. 2620.
#  2646. 2681. 2647. 2425. 2552. 2300. 2589. 2563. 2475. 2548. 2677. 2587.
#  3062. 1873. 2741. 2800. 2494. 2464. 4227. 2851. 2541. 2634. 2711. 2489.
# ...

# %% [markdown]
# ## Questions
# Est-ce qu'on supprime tout ce qui est en lien avec les voitures électriques ? même si il ya des émissions

# %% [markdown]
# ## Remarques
# C'est un peu dommage de devoir supprimer "Fuel consumption" parce qu'il manque pas mal de lignes alors que c'est une feature importante probablement
#
# Est-ce qu'il serait pertinent de tracer la part des pays représentés ? Les marques de voiture (comparer avec le marché si on trouve la donnée)

# %%
drop_col = ["z (Wh/km)","IT","Ernedc (g/km)","Erwltp (g/km)","De", "Vf","Fuel consumption","Electric range (km)"]

df2 = df.drop(columns = drop_col)
df2.dropna()
df2.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-c03dbe70d0ae> in <module>
#       1 drop_col = ["z (Wh/km)","IT","Ernedc (g/km)","Erwltp (g/km)","De", "Vf","Fuel consumption","Fuel consumption"]
#       2
# ----> 3 df2 = df.drop(columns = drop_col)
#       4 df2.dropna()
#       5 df2.info()
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
df["Ewltp (g/km)"].dropna()
# Out:
# 0           46.0
# 1           46.0
# 2           46.0
# 3           46.0
# 4           46.0
#            ...
# 9920103    133.0
# 9920104    148.0
# 9920105    163.0
# 9920106    128.0
# 9920107    150.0
# Name: Ewltp (g/km), Length: 9836149, dtype: float64

# %%
target = df["Ewltp (g/km)"]

# %%
from scipy.stats import pearsonr
#pearsonr(target, df["ec (cm3)"].dropna())

#pearsonr(target[df["ec (cm3)"].notna()],df["ec (cm3)"].dropna())
# Out:
# 83959
